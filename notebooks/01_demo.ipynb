# %% [markdown]
# # SWELM Demo
#
# Quick start demonstration of SWELM functionality.

# %%
import sys
sys.path.append('..')

from src import SWELM, MultilingualEncoder, AdaptiveSampler
from src.utils import set_seed

# %% [markdown]
# ## Initialize SWELM

# %%
set_seed(42)

swelm = SWELM(
    encoder_model="xlm-roberta-base",
    alpha=0.5,
    beta=1.0
)

print(f"SWELM initialized with alpha={swelm.alpha}, beta={swelm.beta}")

# %% [markdown]
# ## Example Usage
#
# TODO: Add examples of computing semantic weights and adaptive sampling
